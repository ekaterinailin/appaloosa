# %%
import warnings
warnings.filterwarnings("ignore")

from appaloosa import RunLC
import os, glob
import pandas as pd

def RunLC_cluster(oid,run,C='05',cluster='M67',LCtype='everest'):
    folder = 'stars_shortlist'
    loc = '{}/{}/results/{}'.format(folder,cluster,run)
    tpf_loc = '{}/{}/ktwo{}-c05_lpd-targ.fits.gz'.format(folder,cluster,oid)
    home = '/home/ekaterina/Documents/appaloosa'
    os.chdir(home)
    if LCtype == 'everest':
        lc_loc = '{}/{}/hlsp_everest_k2_llc_{}-c{}_kepler_v2.0_lc.fits'.format(folder,cluster,oid,C)
        mode = 3
    elif LCtype == 'k2sc':
        #lc_loc = '{}/{}/hlsp_k2sc_k2_llc_{}-c{}_kepler_v2_lc.fits'.format(folder,cluster,oid,C)
        mode = 1
        lc_loc = fetch(oid,C,LCtype)

    fakes = RunLC(lc_loc, dbmode=LCtype, display=True, debug=True, 
                  dofake=True, writeout=False, respath='{}/{}'.format(home,loc),
                  nfake=5, iterations=1200, mode=mode)
    return fakes

def fetch(ID,C,dbmode):
    if dbmode=='k2sc':
        myfile = 'hlsp_k2sc_k2_llc_{}-c{}_kepler_v2_lc.fits'.format(ID,C)
        if glob.glob(myfile)==[]:
            os.system('wget -q http://archive.stsci.edu/hlsps/k2sc/v2/c{2}/{0}00000/hlsp_k2sc_k2_llc_{1}-c{2}_kepler_v2_lc.fits'.format(str(ID)[:4],ID,C))
    elif dbmode=='everest':
        myfile = 'hlsp_everest_k2_llc_{}-c{}_kepler_v2.0_lc.fits'.format(ID,C)
    return myfile

# %%
#everest
clusters = {'NGC_1647':{'C':'13','test':'run_02','LCtype':'everest'},
            'M44':{'C':'05','test':'run_02','LCtype':'everest'},
            'M67':{'C':'05','test':'run_02','LCtype':'everest'},
            'Pleiades':{'C':'04','test':'run_02','LCtype':'everest'}}

# %%
#k2sc
clusters = {'M44':{'C':'05','test':'run_03','LCtype':'k2sc'},
            'M67':{'C':'05','test':'run_03','LCtype':'k2sc'},
            'Pleiades':{'C':'04','test':'run_03','LCtype':'k2sc'}}

# %%
#k2sc run 4
clusters = {'M44':{'C':'05','test':'run_04','LCtype':'k2sc'},
            'M67':{'C':'05','test':'run_04','LCtype':'k2sc'},
            'Pleiades':{'C':'04','test':'run_04','LCtype':'k2sc'}}

# %%
clusters = {'M44':{'C':'05','test':'run_05','LCtype':'k2sc'},
            'M67':{'C':'05','test':'run_05','LCtype':'k2sc'},
            'Pleiades':{'C':'04','test':'run_05','LCtype':'k2sc'}}

# %%
import numpy as np
1/np.sqrt(.2)
# Out:
# 2.23606797749979

# %%
cluster = 'Pleiades'

C = clusters[cluster]['C']
test = clusters[cluster]['test']
LCtype = clusters[cluster]['LCtype']
#ID = 211104312
os.chdir('/home/ekaterina/Documents/appaloosa')
print(os.getcwd())
params = pd.read_csv('stars_shortlist/{0}/{0}_parameter.csv'.format(cluster))
#print(params.tail())
oid_list = params.EPIC.tolist()
print(len(oid_list))
#oid_list.remove(211938860)
print(oid_list[31])
#ID = [211955036, 211972627]
#params.EPIC.to_csv('stars_shortlist/{0}/{0}_IDs_{1}.txt'.format(cluster, test),
                #  header=False, index=False)
    #210804191
# Out:
# /home/ekaterina/Documents/appaloosa
# 804
# 210875952

# %%
#os.chdir('/home/ekaterina/Documents/appaloosa/appaloosa')
for i, oid in enumerate([210803812]):
    print('\nThis is the {}th light curve in the current pipeline.\n'.format(i))
    print(os.getcwd())
    print(oid)
    #if glob.glob('/home/ekaterina/Documents/appaloosa/stars_shortlist/M44/results/run_03/{}_flux.csv'.format(oid))==[]:
    fakes = RunLC_cluster(oid, run=test, C=C, cluster=cluster,LCtype=LCtype)
    #fakes.to_csv("/home/ekaterina/Documents/appaloosa/stars_shortlist/{}/results/{}/{}_{}_allfakes.csv".format(cluster,test,oid,LCtype))
 #   for item in ['flares','flux']:
 #       os.rename("/home/ekaterina/Documents/appaloosa/{}_{}.csv".format(oid,item),
 #                 "/home/ekaterina/Documents/appaloosa/stars_shortlist/{}/results/{}/{}_{}.csv".format(cluster,test,oid,item))

#os.rename('/home/ekaterina/Documents/appaloosa/stars_shortlist/{0}/results/{1}/flarelist.txt'.format(cluster,test),
 #         '/home/ekaterina/Documents/appaloosa/stars_shortlist/{0}/results/{1}/{0}_{1}_flarelist.txt'.format(cluster,test))
# Out:
# This is the 0th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa
# 210875952
# 2018-06-05 08:30:41.138175 GetLC started
# hlsp_k2sc_k2_llc_210875952-c04_kepler_v2_lc.fits
# outfile = /home/ekaterina/research/k2_cluster_flares/aprun/k2sc/210875952-c04_kepler_v2_lc.fits
# dl
# [   0 1497]
# dr
# [1497 3286]
# 0 2018-06-05 08:30:41.264088 MultiFind started
# 1 2018-06-05 08:30:41.753919 MultiFind started
# 2018-06-05 08:30:42.219667 FakeFlares started
# Fake flares durations (1,2) and amplitudes (3,4):
# 1.518785883705128 2.751455707550174 -1.5338792965043513 1.1882012655779386
# Fake flares durations (1,2) and amplitudes (3,4):
# 0.7245001364415361 2.1311742230096185 -1.909200607387501 -0.20797162246986467
# Fake flares durations (1,2) and amplitudes (3,4):
# 1.1515254689017111 2.7816101183000415 -1.4336175420162978 0.7686327369635624
# Fake flares durations (1,2) and amplitudes (3,4):
# ...

# %%
for cluster, p in clusters.items():
    
    C = p['C']
    test = p['test']
    LCtype = p['LCtype']
    os.chdir('/home/ekaterina/Documents/appaloosa')
    print(os.getcwd())
    params = pd.read_csv('stars_shortlist/{0}/{0}_parameter.csv'.format(cluster))
    oid_list = params.EPIC.tolist()
    params.EPIC.to_csv('stars_shortlist/{0}/{0}_IDs_{1}.txt'.format(cluster, test),
                      header=False, index=False)
    for i, oid in enumerate(oid_list):
        print('\nThis is the {}th light curve in the current pipeline.\n'.format(i))
        os.chdir('/home/ekaterina/Documents/appaloosa/stars_shortlist/{0}'.format(cluster))
        print(os.getcwd())
        fetch(oid, C, LCtype)
        if (oid != 211127467) & (oid != 211938860):
            if glob.glob('/home/ekaterina/Documents/appaloosa/stars_shortlist/{}/results/run_{}/{}_flux.csv'.format(cluster,test,oid))==[]:
                RunLC_cluster(oid, run=test, C=C, cluster=cluster,LCtype=LCtype)
        #fakes.to_csv("/home/ekaterina/Documents/appaloosa/stars_shortlist/{}/results/{}/{}_{}_allfakes.csv".format(cluster,test,oid,LCtype))
     #   for item in ['flares','flux']:
     #       os.rename("/home/ekaterina/Documents/appaloosa/{}_{}.csv".format(oid,item),
     #                 "/home/ekaterina/Documents/appaloosa/stars_shortlist/{}/results/{}/{}_{}.csv".format(cluster,test,oid,item))

   # os.rename('/home/ekaterina/Documents/appaloosa/stars_shortlist/{0}/results/{1}/flarelist.txt'.format(cluster,test),
         #     '/home/ekaterina/Documents/appaloosa/stars_shortlist/{0}/results/{1}/{0}_{1}_flarelist.txt'.format(cluster,test))
# Out:
# /home/ekaterina/Documents/appaloosa
#
# This is the 0th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/M44
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/astropy/utils/decorators.py in __get__(self, obj, owner)
#     733         try:
# --> 734             return obj.__dict__[self._key]
#     735         except KeyError:
#
# KeyError: 'data'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-df23dd66157b> in <module>()
#      17         if (oid != 211127467) & (oid != 211938860):
#      18             if glob.glob('/home/ekaterina/Documents/appaloosa/stars_shortlist/{}/results/run_{}/{}_flux.csv'.format(cluster,test,oid))==[]:
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rc, rcParams
rcParams.update({'font.size':12})
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text', usetex=True)

def ratio(fakes, ID, save=False):
    f = fakes[fakes.rec_fake!=0.].sort_values(by='istart_rec')
    f['ed_ratio']=f.ed_rec/f.ed_fake
    f = f.sort_values(by='ed_ratio')
    f = f[f.ed_ratio<1.5]
    f = f[f.ed_rec>1]
    f = f[f.ed_rec<1e4]
    #f['dur'] = (f.istop_rec-f.istart_rec+1)
    f.dur_fake[f.dur_fake >= 0.021 ] = 20
    plt.figure(figsize=(8,6))
    g = f
#     g = f[f.dur_fake >= 0.0208 ]
#     plt.scatter(g.ed_rec,g.ed_ratio,s=g.ed_rec_err/g.ed_rec*1e4, alpha=0.35,
#                 label='$\sigma_{ED}/ED$, injected duration above 30min',
#                 color='green')
#     g = f[f.dur_fake < 0.0208 ]
    plt.scatter(g.ed_rec,g.ed_ratio,s=g.ed_rec_err/g.ed_rec*1e4, alpha=0.35,
                #label='$\sigma_{ED}/ED$, injected duration below 30min',
                color='black')
                #c= np.log(f.dur_fake).tolist(),
                #cmap='Set1')
    plt.axhline(y=1.,color='r')
    plt.axhline(y=1.1,color='r',linestyle='dashed')
    plt.xscale('log')
    plt.yscale('log')
    plt.ylim((0.3,1.2))
    plt.xlim((1,1e4))
    plt.xlabel('recovered ED in s')
    plt.ylabel('recovered fraction of injected ED')
    plt.title('EPIC {}'.format(ID))
    plt.legend(loc=4, frameon=False)
    if save == True:
        plt.savefig('/home/ekaterina/Documents/Flares_in_Clusters_Paper/pic-dump/filter.png'.format(LCtype),dpi=300)
    return

# %%
LCtype = 'k2sc'
test = 'run_05'
oid = 210803812
C = '04'
save=False
fakes = pd.read_csv('/home/ekaterina/research/k2_cluster_flares/aprun/k2sc/{}-c04_kepler_v2_lc.fits_all_fakes.csv'.format(oid))
#falsepos(fakes, oid, save=save)
#fprate(fakes, LCtype, save=save)
#fakes = fakes[fakes.dur_fake < 0.017]
ratio(fakes, oid, save=save)
#ratio_mean(fakes, LCtype, save=save)
fakes = fakes.sort_values(by='dur_fake')[fakes.rec_fake==1.]
fakes['ed_ratio']=fakes.ed_rec/fakes.ed_fake
(fakes.istop_rec-fakes.istart_rec+1).max()
#fakes.groupby(by='dur').count().plot(x='index',y='istart_rec')+
# below = fakes[fakes.ed_ratio < 0.8]
# above = fakes[fakes.ed_ratio > 0.8]
# below.describe()
# Out:
# 1128

# %%
1/24/2
# Out:
# 0.020833333333333332

# %%
def fprate(fakes, LCtype, save=False):
    false = fakes[fakes.rec_fake!=0.].sort_values(by='istart_rec')
    false['ed_ratio']=false.ed_rec/false.ed_fake
    false.ed_ratio = false.ed_ratio.astype('float')
    false = false.sort_values(by='ed_ratio')
    overall_false_pos = false[false.ed_ratio<1.1].shape[0]/false.shape[0]
    #false = false[false.ed_ratio>1.]

    bins = np.power(10,np.arange(-1,5,0.05))
    false['range1'], bins = pd.cut(false.ed_rec, bins, retbins=True,include_lowest=True)
    m = pd.DataFrame()
    m['mean_fp_rate'] = false.groupby('range1').ed_ratio.apply(lambda x: x[x > 1.].shape[0])/false.groupby('range1').ed_ratio.size()
    m['summe'] = false.groupby('range1').ed_ratio.size()
    plt.figure(figsize=(7,5))
    m['binmids'] = (bins[1:]+bins[:-1])/2.
    m = m.dropna(how='any')
    plt.plot(m.binmids,m.mean_fp_rate)
    plt.xscale('log')
    plt.xlabel('recovered ED in s')
    plt.ylabel('false positive rate')
    if save == True:
        plt.savefig('/home/ekaterina/Documents/Flares_in_Clusters_Paper/pic-dump/false_positives_ratio_{}.jpg'.format(LCtype),dpi=300)
    return

# %%
def ratio_mean(fakes, LCtype, save=False):
    f = fakes[fakes.rec_fake!=0.].sort_values(by='istart_rec')
    f['ed_ratio']=f.ed_rec/f.ed_fake
    f = f.sort_values(by='ed_ratio')
    f = f[f.ed_ratio<1.5]
    f = f[f.ed_rec>1]

    bins = np.power(10,np.arange(1,7,0.05))
    f['range1'], bins = pd.cut(f.ed_rec, bins, retbins=True,include_lowest=True)
    m = pd.DataFrame()
    m['mean_ED_corr'] = f.groupby('range1').ed_ratio.mean()
    m['std_ED_corr'] = f.groupby('range1').ed_ratio.std()
    m['binmids'] = (bins[1:]+bins[:-1])/2.
    m = m.dropna(how='any')
    plt.errorbar(m.binmids,m.mean_ED_corr,yerr=m.std_ED_corr)
    plt.xscale('log')
    plt.xlabel('recovered ED in s')
    plt.ylabel('mean fraction of injected energy')
    if save == True:
        plt.savefig('/home/ekaterina/Documents/Flares_in_Clusters_Paper/pic-dump/energy_underestimate_{}.jpg'.format(LCtype),dpi=300)
    return

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rc, rcParams
rcParams.update({'font.size':12})
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text', usetex=True)

def falsepos(fakes, ID, save=False):
  #  fakes = fakes.sort_values(by='istart_rec')
    m = pd.DataFrame()
    bins = np.power(10,np.linspace(0,5.5,50))
    fakes['ed_ratio']=fakes.ed_rec/fakes.ed_fake
    fakes = fakes[fakes.ed_ratio < 1.1]
    fakes = fakes.sort_values(by='ed_fake')#[fakes.ed_fake < 20000]
    fakes['range1'], bins = pd.cut(fakes.ed_fake, bins, retbins=True,include_lowest=True)
    m['mean_ed_fake'] = fakes.groupby('range1').ed_fake.mean()
    m['mean_rec_fake'] = fakes.groupby('range1').rec_fake.mean()
    m['std_rec_fake'] = fakes.groupby('range1').rec_fake.std()

    
    plt.figure(figsize=(7,4))
    h1, edges = np.histogram(fakes.ed_fake, bins=bins)
    h2, edges = np.histogram(fakes.ed_fake[fakes.rec_fake == 1.], bins=bins)
   # plt.xlim(100,1e6)
   # plt.ylim(0,1)
   # ax1.plot((bins[1:]+bins[:-1])/2., h2/h1)
    x = (bins[1:]+bins[:-1])/2.
    y = np.log10(m.mean_rec_fake).tolist()
    yerr = np.log10(m.std_rec_fake).tolist()
    plt.bar(x, m.mean_rec_fake.tolist(),edgecolor='k',
            width=bins[1:]-bins[:-1],
            color='white')#,linestyle='dashed')# yerr=m.std_rec_fake.tolist(),c='k', 
              #   errorevery=6,elinewidth=1,capsize=3)
    plt.title('EPIC {}'.format(ID))
    plt.xlim(12,1e4)
    plt.ylim(0,1)
    plt.ylabel('fraction of recovered flares')
    plt.legend(bbox_to_anchor=(0.9,0.3))

    plt.xscale('log')
    #plt.yscale('log')
    plt.xlabel('injected ED in s')

   # plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)
    if save == True:
        plt.savefig('/home/ekaterina/Documents/Flares_in_Clusters_Paper/pic-dump/recover.png'.format(LCtype),dpi=300)
    return

def color_outlier_red(val,outliers):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    if outliers.size == 0: outliers=[]
    color=[]
    for id_ in val:
        if id_ in list(outliers):
            color.append('red')
        else:
            color.append('black')
    #color = ['red' if val in outliers else 'black'
    return color

# %%
def import_flares(cluster, test, oid):
    
    objectid = str(oid)
    loc = '/home/ekaterina/Documents/appaloosa/stars_shortlist/{}/results/{}'.format(cluster,test)
#    myloc = loc + '_my_flares.txt'
#     try:
#         myflares = pd.read_csv(myloc, names= ['start','stop','istart','istop','comment'])
#     except OSError:
#         myflares = []

    flux = pd.read_csv('{}/{}_flux.csv'.format(loc,oid))#, names= ['time','flux_gap','error','flux_model'])
    flares = pd.read_csv('{}/{}_flares.csv'.format(loc,oid))#, names= ['istart','istop'])
    #print(flux.head())
    return flux, flares

cluster = 'M44'
flux,flares = import_flares(cluster, test, oid)

# %%
fakes = fakes[(fakes.rec_fake != 0.) &  (fakes.ed_rec/fakes.ed_fake > 100)].sort_values(by='istart_rec')
fakes.head()

# %%
start = 0
f = fakes.iloc[start:]#start+40]

for i, row in f.iterrows():
    b,e = int(row.istart_rec), int(row.istop_rec)
    plt.plot(flux.time.iloc[b:e],
             flux.flux_gap.iloc[b:e]+float(i)+100.,
             color='r',linewidth=3)
plt.plot(flux.time.iloc[int(f.istart_rec.iloc[0]):e],
         flux.flux_gap.iloc[int(f.istart_rec.iloc[0]):e],
         color='k',linewidth=.3)

# %%
a = np.array( [item for i, row in fakes.iterrows() 
                       for item in np.arange(row.istart_rec, row.istop_rec,1) ])
plt.hist(a,bins=int(max(a))//100)

# %%
fakes.iloc[start:start+20]
