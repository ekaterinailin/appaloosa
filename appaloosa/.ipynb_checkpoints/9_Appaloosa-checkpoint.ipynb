# %%
import warnings
warnings.filterwarnings("ignore")

from appaloosa import RunLC
import os
import pandas as pd

def RunLC_cluster(oid,run,C='05',cluster='M67',LCtype='everest'):
    folder = 'stars_shortlist'
    loc = '{}/{}/results/{}'.format(folder,cluster,run)
    tpf_loc = '{}/{}/ktwo{}-c05_lpd-targ.fits.gz'.format(folder,cluster,oid)
    if LCtype == 'everest':
        lc_loc = '{}/{}/hlsp_everest_k2_llc_{}-c{}_kepler_v2.0_lc.fits'.format(folder,cluster,oid,C)
        mode = 3
    elif LCtype == 'k2sc':
        lc_loc = '{}/{}/hlsp_k2sc_k2_llc_{}-c{}_kepler_v2_lc.fits'.format(folder,cluster,oid,C)
        mode = 5
    home = '/home/ekaterina/Documents/appaloosa'
    os.chdir(home)
    fakes = RunLC(lc_loc, dbmode=LCtype, display=False, debug=False, 
                  dofake=False, writeout=True, respath='{}/{}'.format(home,loc),
                  nfake=20, iterations=3, mode=mode)
    return fakes

# %%
cluster = 'NGC_1647'
C = '13'
test = 'run_02'
LCtype = 'everest'
#ID = 211104312
os.chdir('/home/ekaterina/Documents/appaloosa')
print(os.getcwd())
params = pd.read_csv('stars_shortlist/{0}/{0}_parameter.csv'.format(cluster))
#print(params.tail())
oid_list = params.EPIC.tolist()
#ID = 246199087
params.EPIC.to_csv('stars_shortlist/{0}/{0}_IDs_{1}.txt'.format(cluster, test),
                  header=False, index=False)
# Out:
# /home/ekaterina/Documents/appaloosa

# %%
clusters = {'NGC_1647':{'C':'13','test':'run_02','LCtype':'everest'},
            'M44':{'C':'05','test':'run_10','LCtype':'everest'},
            'M67':{'C':'05','test':'run_10','LCtype':'everest'},
            'Pleiades':{'C':'04','test':'run_02','LCtype':'everest'}}

# %%
#os.chdir('/home/ekaterina/Documents/appaloosa/appaloosa')
for i, oid in enumerate(oid_list):
    print('\nThis is the {}th light curve in the current pipeline.\n'.format(i))
    print(os.getcwd())
    RunLC_cluster(oid, run=test, C=C, cluster=cluster,LCtype=LCtype)
    #fakes.to_csv("/home/ekaterina/Documents/appaloosa/stars_shortlist/{}/results/{}/{}_{}_allfakes.csv".format(cluster,test,oid,LCtype))
 #   for item in ['flares','flux']:
 #       os.rename("/home/ekaterina/Documents/appaloosa/{}_{}.csv".format(oid,item),
 #                 "/home/ekaterina/Documents/appaloosa/stars_shortlist/{}/results/{}/{}_{}.csv".format(cluster,test,oid,item))

os.rename('/home/ekaterina/Documents/appaloosa/stars_shortlist/{0}/results/{1}/flarelist.txt'.format(cluster,test),
          '/home/ekaterina/Documents/appaloosa/stars_shortlist/{0}/results/{1}/{0}_{1}_flarelist.txt'.format(cluster,test))
# Out:
# This is the 0th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247134522-c13_kepler_v2.0_lc.fits.
#
# This is the 1th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247133675-c13_kepler_v2.0_lc.fits.
#
# This is the 2th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247131381-c13_kepler_v2.0_lc.fits.
#
# This is the 3th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247140208-c13_kepler_v2.0_lc.fits.
#
# This is the 4th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247152215-c13_kepler_v2.0_lc.fits.
#
# This is the 5th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247140140-c13_kepler_v2.0_lc.fits.
#
# This is the 6th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247144554-c13_kepler_v2.0_lc.fits.
#
# This is the 7th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247137318-c13_kepler_v2.0_lc.fits.
#
# This is the 8th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247135189-c13_kepler_v2.0_lc.fits.
#
# This is the 9th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247142250-c13_kepler_v2.0_lc.fits.
#
# This is the 10th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247146947-c13_kepler_v2.0_lc.fits.
#
# This is the 11th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247142909-c13_kepler_v2.0_lc.fits.
#
# This is the 12th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247140858-c13_kepler_v2.0_lc.fits.
#
# This is the 13th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247138835-c13_kepler_v2.0_lc.fits.
#
# This is the 14th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247144738-c13_kepler_v2.0_lc.fits.
#
# This is the 15th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247152702-c13_kepler_v2.0_lc.fits.
#
# This is the 16th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247135437-c13_kepler_v2.0_lc.fits.
#
# This is the 17th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247138301-c13_kepler_v2.0_lc.fits.
#
# This is the 18th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247136661-c13_kepler_v2.0_lc.fits.
#
# This is the 19th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247144273-c13_kepler_v2.0_lc.fits.
#
# This is the 20th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247148453-c13_kepler_v2.0_lc.fits.
#
# This is the 21th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247141048-c13_kepler_v2.0_lc.fits.
#
# This is the 22th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247137978-c13_kepler_v2.0_lc.fits.
#
# This is the 23th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247144482-c13_kepler_v2.0_lc.fits.
#
# This is the 24th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247142189-c13_kepler_v2.0_lc.fits.
#
# This is the 25th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247147971-c13_kepler_v2.0_lc.fits.
#
# This is the 26th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247144857-c13_kepler_v2.0_lc.fits.
#
# This is the 27th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247144760-c13_kepler_v2.0_lc.fits.
#
# This is the 28th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247147055-c13_kepler_v2.0_lc.fits.
#
# This is the 29th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247145590-c13_kepler_v2.0_lc.fits.
#
# This is the 30th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247151969-c13_kepler_v2.0_lc.fits.
#
# This is the 31th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247142225-c13_kepler_v2.0_lc.fits.
#
# This is the 32th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247153285-c13_kepler_v2.0_lc.fits.
#
# This is the 33th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247155058-c13_kepler_v2.0_lc.fits.
#
# This is the 34th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247147539-c13_kepler_v2.0_lc.fits.
#
# This is the 35th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247145246-c13_kepler_v2.0_lc.fits.
#
# This is the 36th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247140556-c13_kepler_v2.0_lc.fits.
#
# This is the 37th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247151912-c13_kepler_v2.0_lc.fits.
#
# This is the 38th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247139810-c13_kepler_v2.0_lc.fits.
#
# This is the 39th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247145041-c13_kepler_v2.0_lc.fits.
#
# This is the 40th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247143463-c13_kepler_v2.0_lc.fits.
#
# This is the 41th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247147343-c13_kepler_v2.0_lc.fits.
#
# This is the 42th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247139663-c13_kepler_v2.0_lc.fits.
#
# This is the 43th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247152473-c13_kepler_v2.0_lc.fits.
#
# This is the 44th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247153808-c13_kepler_v2.0_lc.fits.
#
# This is the 45th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247150352-c13_kepler_v2.0_lc.fits.
#
# This is the 46th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247145033-c13_kepler_v2.0_lc.fits.
#
# This is the 47th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247140823-c13_kepler_v2.0_lc.fits.
#
# This is the 48th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247144563-c13_kepler_v2.0_lc.fits.
#
# This is the 49th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247159506-c13_kepler_v2.0_lc.fits.
#
# This is the 50th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247155886-c13_kepler_v2.0_lc.fits.
#
# This is the 51th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247157956-c13_kepler_v2.0_lc.fits.
#
# This is the 52th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247165313-c13_kepler_v2.0_lc.fits.
#
# This is the 53th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247164111-c13_kepler_v2.0_lc.fits.
#
# This is the 54th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247165305-c13_kepler_v2.0_lc.fits.
#
# This is the 55th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247164503-c13_kepler_v2.0_lc.fits.
#
# This is the 56th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247173226-c13_kepler_v2.0_lc.fits.
#
# This is the 57th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247157742-c13_kepler_v2.0_lc.fits.
#
# This is the 58th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247171135-c13_kepler_v2.0_lc.fits.
#
# This is the 59th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247164884-c13_kepler_v2.0_lc.fits.
#
# This is the 60th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247172423-c13_kepler_v2.0_lc.fits.
#
# This is the 61th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247171017-c13_kepler_v2.0_lc.fits.
#
# This is the 62th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247159731-c13_kepler_v2.0_lc.fits.
#
# This is the 63th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247156683-c13_kepler_v2.0_lc.fits.
#
# This is the 64th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247162918-c13_kepler_v2.0_lc.fits.
#
# This is the 65th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247158149-c13_kepler_v2.0_lc.fits.
#
# This is the 66th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247163176-c13_kepler_v2.0_lc.fits.
#
# This is the 67th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247173570-c13_kepler_v2.0_lc.fits.
#
# This is the 68th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247157298-c13_kepler_v2.0_lc.fits.
#
# This is the 69th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247168832-c13_kepler_v2.0_lc.fits.
#
# This is the 70th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247157714-c13_kepler_v2.0_lc.fits.
#
# This is the 71th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247157066-c13_kepler_v2.0_lc.fits.
#
# This is the 72th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247164142-c13_kepler_v2.0_lc.fits.
#
# This is the 73th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247159741-c13_kepler_v2.0_lc.fits.
#
# This is the 74th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247163194-c13_kepler_v2.0_lc.fits.
#
# This is the 75th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247163048-c13_kepler_v2.0_lc.fits.
#
# This is the 76th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247172859-c13_kepler_v2.0_lc.fits.
#
# This is the 77th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247157340-c13_kepler_v2.0_lc.fits.
#
# This is the 78th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247162706-c13_kepler_v2.0_lc.fits.
#
# This is the 79th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247166643-c13_kepler_v2.0_lc.fits.
#
# This is the 80th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247159388-c13_kepler_v2.0_lc.fits.
#
# This is the 81th light curve in the current pipeline.
#
# /home/ekaterina/Documents/appaloosa/stars_shortlist/NGC_1647/results/run_02
# Writing to /home/ekaterina/research/k2_cluster_flares/aprun/everest/247163921-c13_kepler_v2.0_lc.fits.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rc, rcParams
rcParams.update({'font.size':12})
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text', usetex=True)

def falsepos(fakes):
    false = fakes[fakes.rec_fake!=0.].sort_values(by='istart_rec')
    false['ed_ratio']=false.ed_rec/false.ed_fake
    false = false.sort_values(by='ed_ratio')
    #print(false[false.ed_ratio>1].shape[0]/false.shape[0])
    falsepos = false[false.ed_ratio>1.]


    f, (ax1, ax2,ax3) = plt.subplots(3, sharex=True,figsize=(6,9))

    ax1.hist(fakes.ed_fake, bins=(1,10,100,1000,10000,100000),
             histtype='step',linewidth=2,color='k')
    ax1.set_title('EPIC {}'.format(ID))
    ax1.set_ylabel('\# injected flares')

    ax2.scatter(falsepos.ed_rec,falsepos.ed_ratio, 
                s=falsepos.ed_rec_err/falsepos.ed_rec*1e3,
                color='k',alpha=0.75)
    ax2.axhline(y=1.,color='r')
    ax2.axhline(y=1.1,color='r',linestyle='dashed')
    plt.xscale('log')
    ax2.set_yscale('log')

    plt.xlabel('recovered ED in s')
    ax2.set_ylabel('recovered fraction\n of injected ED')


    ax3.hist(fakes.ed_rec, bins=(1,10,100,1000,10000,100000),
             histtype='step',linewidth=2,color='k')

    ax3.set_ylabel('\# recovered flares')


    f.subplots_adjust(hspace=0)
    plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

    plt.savefig('/home/ekaterina/Documents/Flares_in_Clusters_Paper/pic-dump/false_positives_{}.jpg'.format(LCtype),dpi=300)
    return

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rc, rcParams
rcParams.update({'font.size':12})
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text', usetex=True)

def ratio(fakes):
    f = fakes[fakes.rec_fake!=0.].sort_values(by='istart_rec')
    f['ed_ratio']=f.ed_rec/f.ed_fake
    f = f.sort_values(by='ed_ratio')
    f = f[f.ed_ratio<1.5]
    f = f[f.ed_rec>1]


    plt.figure(figsize=(7,5))

    plt.scatter(f.ed_rec,f.ed_ratio,s=f.ed_rec_err/f.ed_rec*1e3, alpha=0.5,color='k',
                label='$\sigma_{ED}/ED$')
    plt.axhline(y=1.,color='r')
    plt.axhline(y=1.1,color='r',linestyle='dashed')
    plt.xscale('log')
    plt.yscale('log')
    plt.ylim((0.1,1.5))
    plt.xlim((1,1e5))
    plt.xlabel('recovered ED in s')
    plt.ylabel('recovered fraction of injected ED')
    plt.title('EPIC {}'.format(ID))
    plt.legend(loc=4, frameon=False)
    plt.savefig('/home/ekaterina/Documents/Flares_in_Clusters_Paper/pic-dump/ed_ratio_{}.jpg'.format(LCtype),dpi=300)
    return

# %%
def fprate(fakes,LCtype):
    false = fakes[fakes.rec_fake!=0.].sort_values(by='istart_rec')
    false['ed_ratio']=false.ed_rec/false.ed_fake
    false.ed_ratio = false.ed_ratio.astype('float')
    false = false.sort_values(by='ed_ratio')
    overall_false_pos = false[false.ed_ratio>1.].shape[0]/false.shape[0]
    #false = false[false.ed_ratio>1.]

    bins = np.power(10,np.arange(0,6,0.05))
    false['range1'], bins = pd.cut(false.ed_rec, bins, retbins=True,include_lowest=True)
    m = pd.DataFrame()
    m['mean_fp_rate'] = false.groupby('range1').ed_ratio.apply(lambda x: x[x > 1.].shape[0])/false.groupby('range1').ed_ratio.size()
    m['summe'] = false.groupby('range1').ed_ratio.size()
    plt.figure(figsize=(7,5))
    m['binmids'] = (bins[1:]+bins[:-1])/2.
    m = m.dropna(how='any')
    plt.plot(m.binmids,m.mean_fp_rate)
    plt.xscale('log')
    plt.xlabel('recovered ED in s')
    plt.ylabel('false positive rate')
    plt.savefig('/home/ekaterina/Documents/Flares_in_Clusters_Paper/pic-dump/false_positives_ratio_{}.jpg'.format(LCtype),dpi=300)
    return

# %%
def ratio_mean(fakes,LCtype):
    f = fakes[fakes.rec_fake!=0.].sort_values(by='istart_rec')
    f['ed_ratio']=f.ed_rec/f.ed_fake
    f = f.sort_values(by='ed_ratio')
    f = f[f.ed_ratio<1.5]
    f = f[f.ed_rec>1]

    bins = np.power(10,np.arange(0,6,0.05))
    f['range1'], bins = pd.cut(f.ed_rec, bins, retbins=True,include_lowest=True)
    m = pd.DataFrame()
    m['mean_ED_corr'] = f.groupby('range1').ed_ratio.mean()
    m['std_ED_corr'] = f.groupby('range1').ed_ratio.std()
    m['binmids'] = (bins[1:]+bins[:-1])/2.
    m = m.dropna(how='any')
    plt.errorbar(m.binmids,m.mean_ED_corr,yerr=m.std_ED_corr)
    plt.xscale('log')
    plt.xlabel('recovered ED in s')
    plt.ylabel('mean fraction of injected energy')
    plt.savefig('/home/ekaterina/Documents/Flares_in_Clusters_Paper/pic-dump/energy_underestimate_{}.jpg'.format(LCtype),dpi=300)
    return

# %%
LCtype = 'everest'
falsepos(fakes)
fprate(fakes,LCtype)
ratio(fakes)
ratio_mean(fakes,LCtype)

# %%
LCtype = 'everest'
test = 'run_01'
fakes = pd.read_csv("/home/ekaterina/Documents/appaloosa/stars_shortlist/{}/results/{}/{}_{}_allfakes.csv".format(cluster,test,oid,LCtype))
falsepos(fakes)
fprate(fakes,LCtype)
ratio(fakes)
ratio_mean(fakes,LCtype)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9166cd25c9c7> in <module>()
#       1 LCtype = 'everest'
#       2 test = 'run_01'
# ----> 3 fakes = pd.read_csv("/home/ekaterina/Documents/appaloosa/stars_shortlist/{}/results/{}/{}_{}_allfakes.csv".format(cluster,test,oid,LCtype))
#       4 falsepos(fakes)
#       5 fprate(fakes,LCtype)
#
# NameError: name 'oid' is not defined

# %%
LCtype = 'k2sc'
test = 'run_11'
fakes = pd.read_csv("/home/ekaterina/Documents/appaloosa/stars_shortlist/{}/results/{}/{}_{}_allfakes.csv".format(cluster,test,oid,LCtype))

falsepos(fakes)
fprate(fakes,LCtype)
ratio(fakes)
ratio_mean(fakes,LCtype)
