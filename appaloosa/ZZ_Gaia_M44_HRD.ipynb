# %%
import pandas as pd
from astropy.io.votable import parse
#votable = parse("votable.xml")
df = pd.read_csv("/work1/eilin/data/CLUSTERS_01/CLUSTERS_01_M44/m44-result.csv",)
df.columns.values
# Out:
# array(['source_id', 'ra', 'ra_error', 'dec', 'dec_error', 'parallax',
#        'parallax_error', 'phot_g_mean_mag', 'bp_rp', 'radial_velocity',
#        'radial_velocity_error', 'phot_variable_flag', 'teff_val',
#        'teff_percentile_lower', 'teff_percentile_upper', 'a_g_val',
#        'lum_val', 'lum_percentile_lower', 'lum_percentile_upper'],
#       dtype=object)

# %%
df[(df.lum_val.isnull() == False) & (df.teff_val.isnull() == False)]
# Out:
#                 source_id          ra  ra_error        dec  dec_error  \
# 19     659755703071375744  129.433176  0.040998  19.120918   0.030568
# 28     659687980027225088  129.967736  0.033898  18.921760   0.024650
# 30     659752335817016960  129.487278  0.030884  19.066530   0.021508
# 60     659769103369334016  129.413231  0.026572  19.203257   0.017380
# 62     659770168521223936  129.333609  0.037788  19.258531   0.020986
# 64     659756768223263360  129.410037  0.029879  19.158719   0.019519
# 73     659769446966715776  129.383115  0.033318  19.238597   0.023221
# 77     659684131736531712  129.967083  0.059739  18.847131   0.037734
# 84     659773845013175552  129.307060  0.032835  19.312697   0.020123
# 94     659771027514675328  129.435508  0.047786  19.262660   0.031588
# 101    659758005173829888  129.571542  0.023332  19.214314   0.016271
# 115    659684642836021632  130.004623  0.038465  18.884796   0.026956
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df.plot(x='teff_val',y='lum_val',xlim=(7000,3000),ylim=(0.005,500),kind='scatter',logy=True)

# %%
import pandas as pd
import numpy as np

pd.
